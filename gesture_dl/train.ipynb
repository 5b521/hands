# %%
import torch
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torch import nn
import os
import numpy as np
import random
from dataset import IPNHandDataset, zeropad_collate_fn
from lstm_model import SequenceClassification

# %%
# setting seed
def settle_seed(seed= 66):
  os.environ['PYTHONHASHSEED'] = str(seed)
  np.random.seed(seed)
  random.seed(seed)
  torch.manual_seed(seed) 
settle_seed()
run_name = 'normal'
summary_writer = SummaryWriter(f'log/{run_name}')

# %%
origin_dataset = IPNHandDataset('./data/IPN_Hand/ipn_hand.3.csv')
train_dataset, valid_dataset = torch.utils.data.random_split(origin_dataset,[1300, 289])

train_data_loader = DataLoader(train_dataset, batch_size= 32, shuffle= True, collate_fn=zeropad_collate_fn)
valid_data_loader = DataLoader(valid_dataset, batch_size= 32, shuffle= True, collate_fn=zeropad_collate_fn)

# %%
model = SequenceClassification()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr = 0.001,weight_decay= 1e-4)
epochs = 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def evaluate(step):

    model.eval()
    valid_loss = []
    valid_acc = []
    for eval_batch in valid_data_loader:
        X, label = eval_batch
        X = X.to(device)
        label = label.to(device)
        pred = model.forward(X)
        loss = criterion(pred,label)
        acc = sum(torch.argmax(pred,dim = 1) == label) / len(label)
        valid_loss.append(loss)
        valid_acc.append(acc)
    valid_loss = sum(valid_loss) / len(valid_loss) 
    valid_acc = sum(valid_acc) / len(valid_acc)
    # log
    summary_writer.add_scalar('Loss/validate', valid_loss, step)
    summary_writer.add_scalar('Acc/validate', valid_acc, step)
    return valid_loss,valid_acc
def train():
    step = 0 
    model.to(device) 
    min_loss = float('inf') 
    for epoch in range(epochs):
        train_loss = [] 
        train_acc = []
        for batch in train_data_loader:
            model.train() 
            optimizer.zero_grad() 
            X, label = batch 
            # X = X.unsqueeze(1) # in channels 
            X = X.to(device) 
            label = label.to(device)
            pred = model.forward(X) 
            loss = criterion(pred,label) 
            acc = sum(torch.argmax(pred, dim = 1) == label) / len(label) 
            train_loss.append(loss) 
            train_acc.append(acc)
            # log
            summary_writer.add_scalar('Loss/train', loss, step)
            summary_writer.add_scalar('Acc/train', acc, step)
            loss.backward()
            optimizer.step()
            step += 1
            if step % 200 == 0:
                valid_loss,valid_acc = evaluate(step)
                print('Validing: step:%d,mean_loss:%.5f,mean_acc:%.5f' % ( step,valid_loss,valid_acc)) 
                if valid_loss < min_loss:
                    min_loss = valid_loss 
                    torch.save(model.state_dict(), './model/ipn_model_new_73.pt') 
        mean_loss = sum(train_loss) / len(train_loss) 
        mean_acc = sum(train_acc) / len(train_acc) 
        print('Trainging: epoch:%d,step:%d,mean_loss:%.5f,mean_acc:%.5f' % ( epoch,step,mean_loss,mean_acc))
train()
# Out:
# Trainging: epoch:0,step:41,mean_loss:0.92590,mean_acc:0.69695
# Trainging: epoch:1,step:82,mean_loss:0.43739,mean_acc:0.86555
# Trainging: epoch:2,step:123,mean_loss:0.28725,mean_acc:0.90457
# Trainging: epoch:3,step:164,mean_loss:0.23320,mean_acc:0.92668
# Validing: step:200,mean_loss:0.23143,mean_acc:0.92813
# Trainging: epoch:4,step:205,mean_loss:0.17375,mean_acc:0.94954
# Trainging: epoch:5,step:246,mean_loss:0.13490,mean_acc:0.96220
# Trainging: epoch:6,step:287,mean_loss:0.11977,mean_acc:0.96509
# Trainging: epoch:7,step:328,mean_loss:0.08699,mean_acc:0.97256
# Trainging: epoch:8,step:369,mean_loss:0.09170,mean_acc:0.96677
# Validing: step:400,mean_loss:0.27331,mean_acc:0.92813
# Trainging: epoch:9,step:410,mean_loss:0.07713,mean_acc:0.97485
# Trainging: epoch:10,step:451,mean_loss:0.05315,mean_acc:0.98430
# Trainging: epoch:11,step:492,mean_loss:0.04078,mean_acc:0.98887
# Trainging: epoch:12,step:533,mean_loss:0.04067,mean_acc:0.99085
# Trainging: epoch:13,step:574,mean_loss:0.02355,mean_acc:0.99162
# Validing: step:600,mean_loss:0.20479,mean_acc:0.95312
# Trainging: epoch:14,step:615,mean_loss:0.03043,mean_acc:0.99238
# Trainging: epoch:15,step:656,mean_loss:0.02307,mean_acc:0.99466
# Trainging: epoch:16,step:697,mean_loss:0.02683,mean_acc:0.99268
# Trainging: epoch:17,step:738,mean_loss:0.02708,mean_acc:0.99314
# Trainging: epoch:18,step:779,mean_loss:0.04725,mean_acc:0.98537
# Validing: step:800,mean_loss:0.26095,mean_acc:0.95312
# Trainging: epoch:19,step:820,mean_loss:0.05206,mean_acc:0.98201
# Trainging: epoch:20,step:861,mean_loss:0.05867,mean_acc:0.98018
# Trainging: epoch:21,step:902,mean_loss:0.10717,mean_acc:0.97104
# Trainging: epoch:22,step:943,mean_loss:0.05996,mean_acc:0.98171
# Trainging: epoch:23,step:984,mean_loss:0.03595,mean_acc:0.99162
# Validing: step:1000,mean_loss:0.28825,mean_acc:0.93125
# Trainging: epoch:24,step:1025,mean_loss:0.03466,mean_acc:0.99345
# Trainging: epoch:25,step:1066,mean_loss:0.02955,mean_acc:0.99238
# Trainging: epoch:26,step:1107,mean_loss:0.02641,mean_acc:0.99085
# Trainging: epoch:27,step:1148,mean_loss:0.03221,mean_acc:0.99085
# Trainging: epoch:28,step:1189,mean_loss:0.01233,mean_acc:0.99695
# Validing: step:1200,mean_loss:0.24937,mean_acc:0.95312
# Trainging: epoch:29,step:1230,mean_loss:0.00721,mean_acc:0.99771
# Trainging: epoch:30,step:1271,mean_loss:0.00483,mean_acc:0.99924
# Trainging: epoch:31,step:1312,mean_loss:0.01576,mean_acc:0.99619
# Trainging: epoch:32,step:1353,mean_loss:0.04069,mean_acc:0.98857
# Trainging: epoch:33,step:1394,mean_loss:0.08098,mean_acc:0.97409
# Validing: step:1400,mean_loss:0.25561,mean_acc:0.93750
# Trainging: epoch:34,step:1435,mean_loss:0.06554,mean_acc:0.97637
# Trainging: epoch:35,step:1476,mean_loss:0.05978,mean_acc:0.97896
# Trainging: epoch:36,step:1517,mean_loss:0.04469,mean_acc:0.98704
# Trainging: epoch:37,step:1558,mean_loss:0.03403,mean_acc:0.99009
# Trainging: epoch:38,step:1599,mean_loss:0.02625,mean_acc:0.99238
# Validing: step:1600,mean_loss:0.80335,mean_acc:0.84062
# Trainging: epoch:39,step:1640,mean_loss:0.02219,mean_acc:0.99085
# Trainging: epoch:40,step:1681,mean_loss:0.01224,mean_acc:0.99695
# Trainging: epoch:41,step:1722,mean_loss:0.00476,mean_acc:0.99924
# Trainging: epoch:42,step:1763,mean_loss:0.00537,mean_acc:0.99878
# Validing: step:1800,mean_loss:0.24396,mean_acc:0.94375
# Trainging: epoch:43,step:1804,mean_loss:0.01233,mean_acc:0.99848
# Trainging: epoch:44,step:1845,mean_loss:0.00159,mean_acc:1.00000
# Trainging: epoch:45,step:1886,mean_loss:0.00129,mean_acc:1.00000
# Trainging: epoch:46,step:1927,mean_loss:0.00198,mean_acc:1.00000
# Trainging: epoch:47,step:1968,mean_loss:0.00269,mean_acc:0.99924
# Validing: step:2000,mean_loss:0.22174,mean_acc:0.94688
# Trainging: epoch:48,step:2009,mean_loss:0.00334,mean_acc:0.99924
# Trainging: epoch:49,step:2050,mean_loss:0.00213,mean_acc:1.00000
# Trainging: epoch:50,step:2091,mean_loss:0.00155,mean_acc:1.00000
# Trainging: epoch:51,step:2132,mean_loss:0.00349,mean_acc:0.99924
# Trainging: epoch:52,step:2173,mean_loss:0.01381,mean_acc:0.99771
# Validing: step:2200,mean_loss:0.26575,mean_acc:0.94063
# Trainging: epoch:53,step:2214,mean_loss:0.01683,mean_acc:0.99390
# Trainging: epoch:54,step:2255,mean_loss:0.02857,mean_acc:0.99238
# Trainging: epoch:55,step:2296,mean_loss:0.04669,mean_acc:0.98735
# Trainging: epoch:56,step:2337,mean_loss:0.11109,mean_acc:0.96494
# Trainging: epoch:57,step:2378,mean_loss:0.10456,mean_acc:0.96494
# Validing: step:2400,mean_loss:0.34550,mean_acc:0.90312
# Trainging: epoch:58,step:2419,mean_loss:0.04759,mean_acc:0.98399
# Trainging: epoch:59,step:2460,mean_loss:0.05992,mean_acc:0.97774
# Trainging: epoch:60,step:2501,mean_loss:0.06184,mean_acc:0.97668
# Trainging: epoch:61,step:2542,mean_loss:0.05938,mean_acc:0.97866
# Trainging: epoch:62,step:2583,mean_loss:0.02041,mean_acc:0.99238
# Validing: step:2600,mean_loss:0.20985,mean_acc:0.94063
# Trainging: epoch:63,step:2624,mean_loss:0.00499,mean_acc:1.00000
# Trainging: epoch:64,step:2665,mean_loss:0.00151,mean_acc:1.00000
# Trainging: epoch:65,step:2706,mean_loss:0.00094,mean_acc:1.00000
# Trainging: epoch:66,step:2747,mean_loss:0.00101,mean_acc:1.00000
# Trainging: epoch:67,step:2788,mean_loss:0.00073,mean_acc:1.00000
# Validing: step:2800,mean_loss:0.22294,mean_acc:0.95312
# Trainging: epoch:68,step:2829,mean_loss:0.00072,mean_acc:1.00000
# Trainging: epoch:69,step:2870,mean_loss:0.00066,mean_acc:1.00000
# Trainging: epoch:70,step:2911,mean_loss:0.00060,mean_acc:1.00000
# Trainging: epoch:71,step:2952,mean_loss:0.00047,mean_acc:1.00000
# Trainging: epoch:72,step:2993,mean_loss:0.00062,mean_acc:1.00000
# Validing: step:3000,mean_loss:0.21733,mean_acc:0.95312
# Trainging: epoch:73,step:3034,mean_loss:0.00044,mean_acc:1.00000
# Trainging: epoch:74,step:3075,mean_loss:0.00049,mean_acc:1.00000
# Trainging: epoch:75,step:3116,mean_loss:0.00047,mean_acc:1.00000
# Trainging: epoch:76,step:3157,mean_loss:0.00043,mean_acc:1.00000
# Trainging: epoch:77,step:3198,mean_loss:0.00056,mean_acc:1.00000
# Validing: step:3200,mean_loss:0.22248,mean_acc:0.95000
# Trainging: epoch:78,step:3239,mean_loss:0.00078,mean_acc:1.00000
# Trainging: epoch:79,step:3280,mean_loss:0.00309,mean_acc:0.99924
# Trainging: epoch:80,step:3321,mean_loss:0.00198,mean_acc:1.00000
# Trainging: epoch:81,step:3362,mean_loss:0.00188,mean_acc:1.00000
# Validing: step:3400,mean_loss:0.21204,mean_acc:0.95000
# Trainging: epoch:82,step:3403,mean_loss:0.02205,mean_acc:0.99695
# Trainging: epoch:83,step:3444,mean_loss:0.04413,mean_acc:0.98857
# Trainging: epoch:84,step:3485,mean_loss:0.09070,mean_acc:0.97637
# Trainging: epoch:85,step:3526,mean_loss:0.16170,mean_acc:0.95655
# Trainging: epoch:86,step:3567,mean_loss:0.09037,mean_acc:0.96951
# Validing: step:3600,mean_loss:0.26024,mean_acc:0.94063
# Trainging: epoch:87,step:3608,mean_loss:0.08281,mean_acc:0.97104
# Trainging: epoch:88,step:3649,mean_loss:0.04418,mean_acc:0.98628
# Trainging: epoch:89,step:3690,mean_loss:0.03085,mean_acc:0.98933
# Trainging: epoch:90,step:3731,mean_loss:0.01111,mean_acc:0.99771
# Trainging: epoch:91,step:3772,mean_loss:0.02043,mean_acc:0.99390
# Validing: step:3800,mean_loss:0.23487,mean_acc:0.95000
# Trainging: epoch:92,step:3813,mean_loss:0.01346,mean_acc:0.99619
# Trainging: epoch:93,step:3854,mean_loss:0.00777,mean_acc:0.99649
# Trainging: epoch:94,step:3895,mean_loss:0.00709,mean_acc:0.99924
# Trainging: epoch:95,step:3936,mean_loss:0.00605,mean_acc:0.99848
# Trainging: epoch:96,step:3977,mean_loss:0.01522,mean_acc:0.99726
# Validing: step:4000,mean_loss:0.23868,mean_acc:0.94063
# Trainging: epoch:97,step:4018,mean_loss:0.01278,mean_acc:0.99466
# Trainging: epoch:98,step:4059,mean_loss:0.00739,mean_acc:0.99848
# Trainging: epoch:99,step:4100,mean_loss:0.00905,mean_acc:0.99771

# %%
# load tensorboard extension
# %load_ext tensorboard

# %%
# launch tensorboard
# if you are using vscode, use the bottom left "..." button to change the presentation to html
# %tensorboard --logdir=log
